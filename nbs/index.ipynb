# %%
#| hide
import hypersheets as hs
from IPython.display import display, HTML
import matplotlib as mpl
import os
import sys
import shutil

# %%
#| echo: false
#| eval: true

# Get directory name


## Try to remove tree; if failed show an error using try...except on screen
try:
    shutil.rmtree('../index_files')
except OSError as e:
    print ("Error: %s - %s." % (e.filename, e.strerror))
# Out:
# Error: ../index_files - The system cannot find the path specified.

# %%
#| hide
mpl.rcParams['figure.dpi'] = 300

# %% [markdown]
# # hypersheets
#
# > hypersheets

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# # About

# %% [markdown]
# This is a python package, made in nbdev for creating financial tearsheets based on [quanstats](https://github.com/ranaroussi/quantstats).
#
# Documentation can be found [here](https://kgrewal1.github.io/hypersheets/)

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install hypersheets
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# ### Importing of data

# %% [markdown]
# The package provides a wrapper for yfinance's Yahoo API to allow the downloading of price and return date (based on daily adjusted close)

# %%
SPY_prices = hs.utils.download_prices('SPY',  period="5y")
SPY_returns = hs.utils.download_returns('SPY',  period="5y")

# %% [markdown]
# Existing price data data can be easily turned into returns

# %%
QQQ_prices = hs.utils.download_prices('QQQ',  period="5y")
QQQ_returns = hs.utils.prepare_returns(QQQ_prices)

# %% [markdown]
# ### Analysis
# Prebuilt reports functions allow for the quick analysis of stock performance

# %%
#|eval: false
# hs.reports.plots(SPY_returns, QQQ_returns, display=True)

# %% [markdown]
# More detailed html tearsheets can also be produced:

# %%
#|eval: false
hs.reports.html(SPY_returns, QQQ_returns, returns_title = 'SPY', benchmark_title = 'QQQ', download_filename = 'Example_Tearsheet.html', output = False)

# %%
#| echo: false
#| output: asis
# display(HTML('./Example_Tearsheet.html'))

# %% [markdown]
# ### More infomation

# %% [markdown]
# A full list of methods can be generated by:

# %%
hs.utils.__all__
# Out:
# ['mtd',
#  'qtd',
#  'ytd',
#  'pandas_date',
#  'pandas_current_month',
#  'multi_shift',
#  'to_excess_returns',
#  'prepare_returns',
#  'to_returns',
#  'to_prices',
#  'to_log_returns',
#  'log_returns',
#  'exponential_stdev',
#  'download_prices',
#  'download_returns',
#  'prepare_benchmark',
#  'rebase',
#  'group_returns',
#  'aggregate_returns',
#  'prepare_prices',
#  'round_to_closest',
#  'file_stream',
#  'make_index',
#  'make_portfolio']
